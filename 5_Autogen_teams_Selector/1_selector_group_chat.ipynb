# %%
from langchain_google_vertexai import ChatVertexAI

# %%
import asyncio
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.teams import SelectorGroupChat
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_agentchat.conditions import TextMentionTermination
from dotenv import load_dotenv,dotenv_values
import os


load_dotenv()
env_vars = dotenv_values(".env")
api_key = env_vars.get("OPENAI_API_KEY")
model_client = OpenAIChatCompletionClient(model='gpt-4o-mini', api_key=api_key)

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.teams import SelectorGroupChat


planning_agent = AssistantAgent(
    name="PlanningAgent",
    description="An agent for planning tasks, this agent should be the first to engage when given a new task.",
    model_client=model_client,
    system_message="""
    You are a planning agent.
    Your job is to break down complex tasks into smaller, manageable subtasks.
    Your team members are:
        WebSearchAgent: Searches for information
        DataAnalystAgent: Performs calculations

    You only plan and delegate tasks - you do not execute them yourself.

    When assigning tasks, use this format:
    1. <agent> : <task>

    After all tasks are complete, summarize the findings and end with "TERMINATE".
    """,
)

# %%
# from dotenv import load_dotenv

# from langchain_community.utilities import GoogleSerperAPIWrapper

# from autogen_ext.tools.http import HttpTool


# os.environ['SERPER_API_KEY']='bead05022450578faa7498f4c90d85e534c372e0'


# search_tool_wrapper = GoogleSerperAPIWrapper(type='search')

# def search_web(query:str) ->str:
#     """Search the web for the given query and return the results."""
#     try:
#         results = search_tool_wrapper.run(query)
#         return results
#     except Exception as e:
#         print(f"Error occurred while searching the web: {e}")
#         return "No results found."

# %%
import os
TAVILY_API_KEY = os.environ["TAVILY_API_KEY"]

# %%
from dotenv import load_dotenv

from langchain_tavily import TavilySearch

from autogen_ext.tools.http import HttpTool

search_tool_wrapper = TavilySearch(topic = "general",max_results = 1,)

def search_web(query:str) ->str:
    """Search the web for the given query and return the results."""
    try:
        results = search_tool_wrapper.invoke(query)
        return results
    except Exception as e:
        print(f"Error occurred while searching the web: {e}")
        return "No results found."

# %%
def search_web_tool(query:str)-> str:
    # Simulate a web search
    if "2006-2007" in query:
        return """Here are the total points scored by Miami Heat players in the 2006-2007 season:
        Udonis Haslem: 844 points
        Dwayne Wade: 1397 points
        James Posey: 550 points
        ...
        """
    elif "2007-2008" in query:
        return "The number of total rebounds for Dwayne Wade in the Miami Heat season 2007-2008 is 214."
    elif "2008-2009" in query:
        return "The number of total rebounds for Dwayne Wade in the Miami Heat season 2008-2009 is 398."
    return "No data found."

# %%
model_client = OpenAIChatCompletionClient(model='gpt-4o-mini', api_key=api_key)

# %%
web_search_agent = AssistantAgent(
    name = 'WebSearchAgent',
    description= 'An agent for searching the web for information.',
    model_client=model_client,
    tools = [search_web],
    reflect_on_tool_use=False,
    system_message='''
        You are a web search agent.
        Your only tool is search_web - use it to find the information you need.

        You make only one search call at a time.
        
        Once you have the results, you never do calculations or data analysis on them.
    ''',
)

# %%
def percentage_change_tool(start:float, end:float) -> float:
    # Calculate percentage change
    if start == 0:
        return 0
    return ((end - start) / start) * 100

# %%
data_analyst_agent = AssistantAgent(
    name = 'DataAnalystAgent',
    description= 'An agent for performing calculations and data analysis.',
    model_client=model_client,
    tools= [percentage_change_tool],
    system_message='''
        You are a data analyst agent.
        Given the tasks you have been assigned, you should analyze the data and provide results using the tools provided (percentage_change_tool).

        If you have not seen the data, ask for it.

    ''',
)

# %%
from autogen_agentchat.conditions import TextMentionTermination,MaxMessageTermination

text_mention_termination = TextMentionTermination('TERMINATE')
max_message_termination = MaxMessageTermination(max_messages=20)
combined_termination = text_mention_termination | max_message_termination

# %%
selector_prompt = '''
Select an agent to perform the task.

{roles}

current conversation history :
{history}

Read the above conversation, then select an agent from {participants} to perform the next task.
Make sure that the planning agent has assigned task before other agents start working.
Only select one agent.
'''

# %%
planning_agent.description
# Out:
# 'An agent for planning tasks, this agent should be the first to engage when given a new task.'

# %%
selector_team = SelectorGroupChat(
    participants=[planning_agent, web_search_agent, data_analyst_agent],
    model_client=model_client,
    termination_condition=combined_termination,
    selector_prompt=selector_prompt,
    allow_repeated_speaker=True)

# %%
task = "Who was the Miami Heat player with the highest point in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?"

# %%
from autogen_agentchat.ui import Console

await Console(selector_team.run_stream(task=task))
# Out:
# ---------- TextMessage (user) ----------
# Who was the Miami Heat player with the highest point in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?
# ---------- TextMessage (PlanningAgent) ----------
# To provide a comprehensive response to your inquiry, we need to fulfill these tasks:
#
# 1. Identify the Miami Heat player with the highest points during the 2006-2007 NBA season.
# 2. Calculate the difference in total rebounds for this player between the 2007-2008 and 2008-2009 seasons. Then, compute the percentage change based on these figures.
#
# Let's start by assigning tasks.
#
# 1. WebSearchAgent: Research which Miami Heat player had the most points during the 2006-2007 season.
# 2. WebSearchAgent: Find the total rebounds for this player during the 2007-2008 and 2008-2009 seasons.
# 3. DataAnalystAgent: Calculate the percentage change in total rebounds between the 2007-2008 and 2008-2009 seasons based on the retrieved data.
#
# Once these tasks have been completed, we'll summarize the findings.
# ---------- ToolCallRequestEvent (WebSearchAgent) ----------
# [FunctionCall(id='call_Z8m1fRkulOowPAezRmOl4Hc3', arguments='{"query":"Miami Heat highest scorer 2006-2007 NBA season"}', name='search_web')]
# ---------- ToolCallExecutionEvent (WebSearchAgent) ----------
# [FunctionExecutionResult(content='{\'query\': \'Miami Heat highest scorer 2006-2007 NBA season\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'url\': \'https://www.landofbasketball.com/stats_by_team/2006_2007_heat_rs.htm\', \'title\': \'2006-07 Miami Heat Player Stats - Regular Season\', \'content\': "2006-07 Miami Heat -. NBA Regular Season Stats ; Dwyane Wade · 51, 37.9 ; Shaquille O\'Neal · 40, 28.4 ; Jason Kapono · 67, 26.4 ; Jason Williams · 61, 30.6", \'score\': 0.8440111, \'raw_content\': None}], \'response_time\': 1.45}', name='search_web', call_id='call_Z8m1fRkulOowPAezRmOl4Hc3', is_error=False)]
# ---------- ToolCallSummaryMessage (WebSearchAgent) ----------
# {'query': 'Miami Heat highest scorer 2006-2007 NBA season', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.landofbasketball.com/stats_by_team/2006_2007_heat_rs.htm', 'title': '2006-07 Miami Heat Player Stats - Regular Season', 'content': "2006-07 Miami Heat -. NBA Regular Season Stats ; Dwyane Wade · 51, 37.9 ; Shaquille O'Neal · 40, 28.4 ; Jason Kapono · 67, 26.4 ; Jason Williams · 61, 30.6", 'score': 0.8440111, 'raw_content': None}], 'response_time': 1.45}
# ---------- TextMessage (PlanningAgent) ----------
# Based on the search results, the Miami Heat player with the most points during the 2006-2007 NBA season was Dwyane Wade.
#
# Now, let's proceed to the next task.
#
# 1. WebSearchAgent: Find the total rebounds for Dwyane Wade during the 2007-2008 and 2008-2009 seasons.
# ---------- ToolCallRequestEvent (WebSearchAgent) ----------
# [FunctionCall(id='call_P8P28AGnatYN6zaVi8qPK0Sj', arguments='{"query": "Dwyane Wade total rebounds 2007-2008 NBA season"}', name='search_web'), FunctionCall(id='call_kl2cX0IRHVkCTNtW99KCSjJe', arguments='{"query": "Dwyane Wade total rebounds 2008-2009 NBA season"}', name='search_web')]
# ---------- ToolCallExecutionEvent (WebSearchAgent) ----------
# [FunctionExecutionResult(content="{'query': 'Dwyane Wade total rebounds 2007-2008 NBA season', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.statmuse.com/nba/ask/dwyane-wade-2008-nba-stats', 'title': 'Dwyane Wade 2008 NBA Stats | StatMuse', 'content': 'Dwyane Wade averaged 24.6 points, 6.9 assists and 4.2 rebounds in 51 games in 2007-08. He was selected to play in his fourth All-Star game.', 'score': 0.93554133, 'raw_content': None}], 'response_time': 1.07}", name='search_web', call_id='call_P8P28AGnatYN6zaVi8qPK0Sj', is_error=False), FunctionExecutionResult(content="{'query': 'Dwyane Wade total rebounds 2008-2009 NBA season', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.statmuse.com/nba/ask/dwyane-wade-2008-2009-stats', 'title': 'Dwyane Wade 2008 2009 Stats | StatMuse', 'content': 'Dwyane Wade averaged 30.2 points, 7.5 assists and 5.0 rebounds in 79 games in 2008-09. He was selected to play in his fifth All-Star game.', 'score': 0.9255605, 'raw_content': None}], 'response_time': 1.82}", name='search_web', call_id='call_kl2cX0IRHVkCTNtW99KCSjJe', is_error=False)]
# ---------- ToolCallSummaryMessage (WebSearchAgent) ----------
# {'query': 'Dwyane Wade total rebounds 2007-2008 NBA season', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.statmuse.com/nba/ask/dwyane-wade-2008-nba-stats', 'title': 'Dwyane Wade 2008 NBA Stats | StatMuse', 'content': 'Dwyane Wade averaged 24.6 points, 6.9 assists and 4.2 rebounds in 51 games in 2007-08. He was selected to play in his fourth All-Star game.', 'score': 0.93554133, 'raw_content': None}], 'response_time': 1.07}
# {'query': 'Dwyane Wade total rebounds 2008-2009 NBA season', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.statmuse.com/nba/ask/dwyane-wade-2008-2009-stats', 'title': 'Dwyane Wade 2008 2009 Stats | StatMuse', 'content': 'Dwyane Wade averaged 30.2 points, 7.5 assists and 5.0 rebounds in 79 games in 2008-09. He was selected to play in his fifth All-Star game.', 'score': 0.9255605, 'raw_content': None}], 'response_time': 1.82}
# ---------- ThoughtEvent (DataAnalystAgent) ----------
# Dwyane Wade averaged:
#
# - 4.2 rebounds in the 2007-2008 season over 51 games.
# - 5.0 rebounds in the 2008-2009 season over 79 games.
#
# Now, let's calculate the percentage change in his total rebounds between these seasons.
# ---------- ToolCallRequestEvent (DataAnalystAgent) ----------
# [FunctionCall(id='call_STqo4atdupQyxYGDn04xlhc4', arguments='{"start":4.2,"end":5.0}', name='percentage_change_tool')]
# ---------- ToolCallExecutionEvent (DataAnalystAgent) ----------
# [FunctionExecutionResult(content='19.047619047619044', name='percentage_change_tool', call_id='call_STqo4atdupQyxYGDn04xlhc4', is_error=False)]
# ---------- ToolCallSummaryMessage (DataAnalystAgent) ----------
# 19.047619047619044
# ---------- TextMessage (PlanningAgent) ----------
# We have gathered the necessary data:
#
# - Dwyane Wade, who was the Miami Heat player with the highest points during the 2006-2007 season, averaged 4.2 rebounds per game in the 2007-2008 season and 5.0 rebounds per game in the 2008-2009 season.
#
# The Data Analyst Agent calculated that there was a 19.05% increase in Dwyane Wade's total rebounds from the 2007-2008 season to the 2008-2009 season.
#
# TERMINATE
# TaskResult(messages=[TextMessage(id='7d79691e-a4b9-4fb0-901e-3132f2cc9828', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 8, 14, 9, 14, 425379, tzinfo=datetime.timezone.utc), content='Who was the Miami Heat player with the highest point in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?', type='TextMessage'), TextMessage(id='8800c856-32aa-4622-8425-e35b98ee75d0', source='PlanningAgent', models_usage=RequestUsage(prompt_tokens=161, completion_tokens=187), metadata={}, created_at=datetime.datetime(2025, 8, 8, 14, 9, 21, 410874, tzinfo=datetime.timezone.utc), content="To provide a comprehensive response to your inquiry, we need to fulfill these tasks:\n\n1. Identify the Miami Heat player with the highest points during the 2006-2007 NBA season.\n2. Calculate the difference in total rebounds for this player between the 2007-2008 and 2008-2009 seasons. Then, compute the percentage change based on these figures.\n\nLet's start by assigning tasks. \n\n1. WebSearchAgent: Research which Miami Heat player had the most points during the 2006-2007 season.\n2. WebSearchAgent: Find the total rebounds for this player during the 2007-2008 and 2008-2009 seasons.\n3. DataAnalystAgent: Calculate the percentage change in total rebounds between the 2007-2008 and 2008-2009 seasons based on the retrieved data.\n\nOnce these tasks have been completed, we'll summarize the findings.", type='TextMessage'), ToolCallRequestEvent(id='b43ea1e8-5b6c-4b63-b864-22bf62322ed0', source='WebSearchAgent', models_usage=RequestUsage(prompt_tokens=352, completion_tokens=25), metadata={}, created_at=datetime.datetime(2025, 8, 8, 14, 9, 24, 336834, tzinfo=datetime.timezone.utc), content=[FunctionCall(id='call_Z8m1fRkulOowPAezRmOl4Hc3', arguments='{"query":"Miami Heat highest scorer 2006-2007 NBA season"}', name='search_web')], type='ToolCallRequestEvent'), ToolCallExecutionEvent(id='6f4ca2f6-7c72-498f-aa81-adcbafdb8f0d', source='WebSearchAgent', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 8, 14, 9, 26, 726785, tzinfo=datetime.timezone.utc), content=[FunctionExecutionResult(content='{\'query\': \'Miami Heat highest scorer 2006-2007 NBA season\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'url\': \'https://www.landofbasketball.com/stats_by_team/2006_2007_heat_rs.htm\', \'title\': \'2006-07 Miami Heat Player Stats - Regular Season\', \'content\': "2006-07 Miami Heat -. NBA Regular Season Stats ; Dwyane Wade · 51, 37.9 ; Shaquille O\'Neal · 40, 28.4 ; Jason Kapono · 67, 26.4 ; Jason Williams · 61, 30.6", \'score\': 0.8440111, \'raw_content\': None}], \'response_time\': 1.45}', name='search_web', call_id='call_Z8m1fRkulOowPAezRmOl4Hc3', is_error=False)], type='ToolCallExecutionEvent'), ToolCallSummaryMessage(id='ce3cbcfe-96fb-4e00-9220-3c1c6c7e5d0b', source='WebSearchAgent', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 8, 14, 9, 26, 726785, tzinfo=datetime.timezone.utc), content='{\'query\': \'Miami Heat highest scorer 2006-2007 NBA season\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'url\': \'https://www.landofbasketball.com/stats_by_team/2006_2007_heat_rs.htm\', \'title\': \'2006-07 Miami Heat Player Stats - Regular Season\', \'content\': "2006-07 Miami Heat -. NBA Regular Season Stats ; Dwyane Wade · 51, 37.9 ; Shaquille O\'Neal · 40, 28.4 ; Jason Kapono · 67, 26.4 ; Jason Williams · 61, 30.6", \'score\': 0.8440111, \'raw_content\': None}], \'response_time\': 1.45}', type='ToolCallSummaryMessage', tool_calls=[FunctionCall(id='call_Z8m1fRkulOowPAezRmOl4Hc3', arguments='{"query":"Miami Heat highest scorer 2006-2007 NBA season"}', name='search_web')], results=[FunctionExecutionResult(content='{\'query\': \'Miami Heat highest scorer 2006-2007 NBA season\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'u ...

# %%
# With real web search


from autogen_agentchat.ui import Console

await Console(selector_team.run_stream(task=task))
# Out:
# ---------- TextMessage (user) ----------
# Who was the Miami Heat player with the highest point in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?
# ---------- TextMessage (PlanningAgent) ----------
# To address your inquiry, we have already completed the following tasks:
#
# 1. Identified the Miami Heat player with the highest points during the 2006-2007 season - Dwyane Wade.
# 2. Calculated the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons.
#
# Here's the summary:
# - **2006-2007 Season:** Dwyane Wade was the player with the highest points for the Miami Heat.
# - **Total Rebounds:**
#   - 2007-2008 Season: 4.2 rebounds per game.
#   - 2008-2009 Season: 5.0 rebounds per game.
#
# The percentage increase in his rebounds from the 2007-2008 season to the 2008-2009 season was 19.05%.
#
# TERMINATE
# TaskResult(messages=[TextMessage(id='fea1690f-358e-4793-b826-b63a44afe2e5', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 8, 14, 9, 43, 111123, tzinfo=datetime.timezone.utc), content='Who was the Miami Heat player with the highest point in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?', type='TextMessage'), TextMessage(id='0f42f932-c195-42e1-9d7a-34705ed9ce8e', source='PlanningAgent', models_usage=RequestUsage(prompt_tokens=1116, completion_tokens=174), metadata={}, created_at=datetime.datetime(2025, 8, 8, 14, 9, 49, 355571, tzinfo=datetime.timezone.utc), content="To address your inquiry, we have already completed the following tasks:\n\n1. Identified the Miami Heat player with the highest points during the 2006-2007 season - Dwyane Wade.\n2. Calculated the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons.\n\nHere's the summary:\n- **2006-2007 Season:** Dwyane Wade was the player with the highest points for the Miami Heat.\n- **Total Rebounds:** \n  - 2007-2008 Season: 4.2 rebounds per game.\n  - 2008-2009 Season: 5.0 rebounds per game.\n  \nThe percentage increase in his rebounds from the 2007-2008 season to the 2008-2009 season was 19.05%.\n\nTERMINATE", type='TextMessage')], stop_reason="Text 'TERMINATE' mentioned")

# %%
state = await selector_team.save_state()

# %%
state
# Out:
# {'type': 'TeamState',
#  'version': '1.0.0',
#  'agent_states': {'PlanningAgent': {'type': 'ChatAgentContainerState',
#    'version': '1.0.0',
#    'agent_state': {'type': 'AssistantAgentState',
#     'version': '1.0.0',
#     'llm_context': {'messages': [{'content': 'Who was the Miami Heat player with the highest point in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?',
#        'source': 'user',
#        'type': 'UserMessage'},
#       {'content': "To provide a comprehensive response to your inquiry, we need to fulfill these tasks:\n\n1. Identify the Miami Heat player with the highest points during the 2006-2007 NBA season.\n2. Calculate the difference in total rebounds for this player between the 2007-2008 and 2008-2009 seasons. Then, compute the percentage change based on these figures.\n\nLet's start by assigning tasks. \n\n1. WebSearchAgent: Research which Miami Heat player had the most points during the 2006-2007 season.\n2. WebSearchAgent: Find the total rebounds for this player during the 2007-2008 and 2008-2009 seasons.\n3. DataAnalystAgent: Calculate the percentage change in total rebounds between the 2007-2008 and 2008-2009 seasons based on the retrieved data.\n\nOnce these tasks have been completed, we'll summarize the findings.",
#        'thought': None,
#        'source': 'PlanningAgent',
#        'type': 'AssistantMessage'},
#       {'content': '{\'query\': \'Miami Heat highest scorer 2006-2007 NBA season\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'url\': \'https://www.landofbasketball.com/stats_by_team/2006_2007_heat_rs.htm\', \'title\': \'2006-07 Miami Heat Player Stats - Regular Season\', \'content\': "2006-07 Miami Heat -. NBA Regular Season Stats ; Dwyane Wade · 51, 37.9 ; Shaquille O\'Neal · 40, 28.4 ; Jason Kapono · 67, 26.4 ; Jason Williams · 61, 30.6", \'score\': 0.8440111, \'raw_content\': None}], \'response_time\': 1.45}',
#        'source': 'WebSearchAgent',
#        'type': 'UserMessage'},
#       {'content': "Based on the search results, the Miami Heat player with the most points during the 2006-2007 NBA season was Dwyane Wade.\n\nNow, let's proceed to the next task.\n\n1. WebSearchAgent: Find the total rebounds for Dwyane Wade during the 2007-2008 and 2008-2009 seasons.",
#        'thought': None,
#        'source': 'PlanningAgent',
#        'type': 'AssistantMessage'},
#       {'content': "{'query': 'Dwyane Wade total rebounds 2007-2008 NBA season', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.statmuse.com/nba/ask/dwyane-wade-2008-nba-stats', 'title': 'Dwyane Wade 2008 NBA Stats | StatMuse', 'content': 'Dwyane Wade averaged 24.6 points, 6.9 assists and 4.2 rebounds in 51 games in 2007-08. He was selected to play in his fourth All-Star game.', 'score': 0.93554133, 'raw_content': None}], 'response_time': 1.07}\n{'query': 'Dwyane Wade total rebounds 2008-2009 NBA season', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.statmuse.com/nba/ask/dwyane-wade-2008-2009-stats', 'title': 'Dwyane Wade 2008 2009 Stats | StatMuse', 'content': 'Dwyane Wade averaged 30.2 points, 7.5 assists and 5.0 rebounds in 79 games in 2008-09. He was selected to play in his fifth All-Star game.', 'score': 0.9255605, 'raw_content': None}], 'response_time': 1.82}",
#        'source': 'WebSearchAgent',
#        'type': 'UserMessage'},
#       {'content': '19.047619047619044',
#        'source': 'DataAnalystAgent',
#        'type': 'UserMessage'},
#       {'content': "We have gathered the necessary data:\n\n- Dwyane Wade, who was the Miami Heat player with the highest points during the 2006-2007 season, averaged 4.2 rebounds per game in the 2007-2008 season and 5.0 rebounds per game in the 2008-2009 season.\n\nThe Data Analyst Agent calculated that there was a 19.05% increase in Dwyane Wade's total rebounds from the 2007-2008 season to the 2008-2009 season.\n\nTERMINATE",
#        'thought': None,
#        'source': 'PlanningAgent',
#        'type': 'AssistantMessage'},
#       {'content': 'Who was the Miami Heat player with the highest point in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?',
#        'source': 'user',
#        'type': 'UserMessage'},
#       {'content': "To address your inquiry, we have already completed the following tasks:\n\n1. Identified the Miami Heat player with the highest points during the 2006-2007 season - Dwyane Wade.\n2. Calculated the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons.\n\nHere's the summary:\n- **2006-2007 Season:** Dwyane Wade was the player with the highest points for the Miami Heat.\n- **Total Rebounds:** \n  - 2007-2008 Season: 4.2 rebounds per game.\n  - 2008-2009 Season: 5.0 rebounds per game.\n  \nThe percentage increase in his rebounds from the 2007-2008 season to the 2008-2009 season was 19.05%.\n\nTERMINATE",
#        'thought': None,
#        'source': 'PlanningAgent',
#        'type': 'AssistantMessage'}]}},
#    'message_buffer': []},
#   'WebSearchAgent': {'type': 'ChatAgentContainerState',
#    'version': '1.0.0',
#    'agent_state': {'type': 'AssistantAgentState',
#     'version': '1.0.0',
#     'llm_context': {'messages': [{'content': 'Who was the Miami Heat player with the highest point in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?',
#        'source': 'user',
#        'type': 'UserMessage'},
#       {'content': "To provide a comprehensive response to your inquiry, we need to fulfill these tasks:\n\n1. Identify the Miami Heat player with the highest points during the 2006-2007 NBA season.\n2. Calculate the difference in total rebounds for this player between the 2007-2008 and 2008-2009 seasons. Then, compute the percentage change based on these figures.\n\nLet's start by assigning tasks. \n\n1. WebSearchAgent: Research which Miami Heat player had the most points during the 2006-2007 season.\n2. WebSearchAgent: Find the total rebounds for this player during the 2007-2008 and 2008-2009 seasons.\n3. DataAnalystAgent: Calculate the percentage change in total rebounds between the 2007-2008 and 2008-2009 seasons based on the retrieved data.\n\nOnce these tasks have been completed, we'll summarize the findings.",
#        'source': 'PlanningAgent',
#        'type': 'UserMessage'},
#       {'content': [{'id': 'call_Z8m1fRkulOowPAezRmOl4Hc3',
#          'arguments': '{"query":"Miami Heat highest scorer 2006-2007 NBA season"}',
#          'name': 'search_web'}],
#        'thought': None,
#        'source': 'WebSearchAgent',
#        'type': 'AssistantMessage'},
#       {'content': [{'content': '{\'query\': \'Miami Heat highest scorer 2006-2007 NBA season\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'url\': \'https://www.landofbasketball.com/stats_by_team/2006_2007_heat_rs.htm\', \'title\': \'2006-07 Miami Heat Player Stats - Regular Season\', \'content\': "2006-07 Miami Heat -. NBA Regular Season Stats ; Dwyane Wade · 51, 37.9 ; Shaquille O\'Neal · 40, 28.4 ; Jason Kapono · 67, 26.4 ; Jason Williams · 61, 30.6", \'score\': 0.8440111, \'raw_content\': None}], \'response_time\': 1.45}',
#          'name': 'search_web',
#          'call_id': 'call_Z8m1fRkulOowPAezRmOl4Hc3',
#          'is_error': False}],
#        'type': 'FunctionExecutionResultMessage'},
#       {'content': "Based on the search results, the Miami Heat player with the most points during the 2006-2007 NBA season was Dwyane Wade.\n\nNow, let's proceed to the next task.\n\n1. WebSearchAgent: Find the total rebounds for Dwyane Wade during the 2007-2008 and 2008-2009 seasons.",
#        'source': 'PlanningAgent',
#        'type': 'UserMessage'},
#       {'content': [{'id': 'call_P8P28AGnatYN6zaVi8qPK0Sj',
#          'arguments': '{"query": "Dwyane Wade total rebounds 2007-2008 NBA season"}',
#          'name': 'search_web'},
#         {'id': 'call_kl2cX0IRHVkCTNtW99KCSjJe',
#          'arguments': '{"query": "Dwyane Wade total rebounds 2008-2009 NBA season"}',
#          'name': 'search_web'}],
#        'thought': None,
#        'source': 'WebSearchAgent',
#        'type': 'AssistantMessage'},
#       {'content': [{'content': "{'query': 'Dwyane Wade total rebounds 2007-2008 NBA season', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.statmuse.com/nba/ask/dwyane-wade-2008-nba-stats', 'title': 'Dwyane Wade 2008 NBA Stats | StatMuse', 'content': 'Dwyane Wade averaged 24.6 points, 6.9 assists and 4.2 rebounds in 51 games in 2007-08. He was selected to play in his fourth All-Star game.', 'score': 0.93554133, 'raw_content': None}], 'response_time': 1.07}",
#          'name': 'search_web',
#          'call_id': 'call_P8P28AGnatYN6zaVi8qPK0Sj',
#          'is_error': False},
#         {'content': "{'query': 'Dwyane Wade total rebounds 2008-2009 NBA season', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.statmuse.com/nba/ask/dwyane-wade-2008-2009-stats', 'title': 'Dwyane Wade 2008 2009 Stats | StatMuse', 'content': 'Dwyane Wade averaged 30.2 points, 7.5 assists and 5.0 rebounds in 79 games in 2008-09. He was selected to play in his fifth All-Star game.', 'score': 0.9255605, 'raw_content': None}], 'response_time': 1.82}",
#          'name': 'search_web',
#          'call_id': 'call_kl2cX0IRHVkCTNtW99KCSjJe',
#          'is_error': False}],
#        'type': 'FunctionExecutionResultMessage'}]}},
#    'message_buffer': [{'id': '725cd0ec-7b63-4dda-8a44-2ada7de51579',
#      'source': 'DataAnalystAgent',
#      'models_usage': None,
#      'metadata': {},
#      'created_at': datetime.datetime(2025, 8, 8, 14, 9, 39, 214588, tzinfo=datetime.timezone.utc),
#      'content': '19.047619047619044',
#      'type': 'ToolCallSummaryMessage',
#      'tool_calls': [{'id': 'call_STqo4atdupQyxYGDn04xlhc4',
#        'arguments': '{"start":4.2,"end":5.0}',
#        'name': 'percentage_change_tool'}],
#      'results': [{'content': '19.047619047619044',
#        'name': 'percentage_change_tool',
#        'call_id': 'call_STqo4atdupQyxYGDn04xlhc4',
#        'is_error': False}]},
#     {'id': '5e275e21-c45a-4831-87c6-3e15d95451e1',
#      'source': 'PlanningAgent',
#      'models_usage': {'prompt_tokens': 947, 'completion_tokens': 113},
#      'metadata': {},
#      'created_at': datetime.datetime(2025, 8, 8, 14, 9, 43, 64761, tzinfo=datetime.timezone.utc),
#      'content': "We have gathered the necessary data:\n\n- Dwyane Wade, who was the Miami Heat player with the highest points during the 2006-2007 season, averaged 4.2 rebounds per game in the 2007-2008 season and 5.0 rebounds per game in the 2008-2009 season.\n\nThe Data Analyst Agent calculated that there was a 19.05% increase in Dwyane Wade's total rebounds from the 2007-2008 season to the 2008-2009 season.\n\nTERMINATE",
#      'type': 'TextMessage'},
#     {'id': 'fea1690f-358e-4793-b826-b63a44afe2e5',
#      'source': 'user',
#      'models_usage': None,
#      'metadata': {},
#      'created_at': datetime.datetime(2025, 8, 8, 14, 9, 43, 111123, tzinfo=datetime.timezone.utc),
#      'content': 'Who was the Miami Heat player with the highest point in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?',
#      'type': 'TextMessage'},
#     {'id': '0f42f932-c195-42e1-9d7a-34705ed9ce8e',
#      'source': 'PlanningAgent',
#      'models_usage': {'prompt_tokens': 1116, 'completion_tokens': 174},
#      'metadata': {},
#      'created_at': datetime.datetime(2025, 8, 8, 14, 9, 49, 355571, tzinfo=datetime.timezone.utc),
#      'content': "To address your inquiry, we have already completed the following tasks:\n\n1. Identified the Miami Heat player with the highest points during the 2006-2007 season - Dwyane Wade.\n2. Calculated the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons.\n\nHere's the summary:\n- **2006-2007 Season:** Dwyane Wade was the player with the highest points for the Miami Heat.\n- **Total Rebounds:** \n  - 2007-2008 Season: 4.2 rebounds per game.\n  - 2008-2009 Season: 5.0 rebounds per game.\n  \nThe percentage increase in his rebounds from the 2007-2008 season to the 2008-2009 season was 19.05%.\n\nTERMINATE",
#      'type': 'TextMessage'}]},
#   'DataAnalystAgent': {'type': 'ChatAgentContainerState',
#    'version': '1.0.0',
#    'agent_state': {'type': 'AssistantAgentState',
#     'version': '1.0.0',
#     'llm_context': {'messages': [{'content': 'Who was the Miami Heat player with the highest point in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?',
#        'source': 'user',
#        'type': 'UserMessage'},
#       {'content': "To provide a comprehensive response to your inquiry, we need to fulfill these tasks:\n\n1. Identify the Miami Heat player with the highest points during the 2006-2007 NBA season.\n2. Calculate the difference in total rebounds for this player between the 2007-2008 and 2008-2009 seasons. Then, compute the percentage change based on these figures.\n\nLet's start by assigning tasks. \n\n1. WebSearchAgent: Research which Miami Heat player had the most points during the 2006-2007 season.\n2. WebSearchAgent: Find the total rebounds for this player during the 2007-2008 and 2008-2009 seasons.\n3. DataAnalystAgent: Calculate the percentage change in total rebounds between the 2007-2008 and 2008-2009 seasons based on the retrieved data.\n\nOnce these tasks have been completed, we'll summarize the findings.",
#        'source': 'PlanningAgent',
#        'type': 'UserMessage'},
#       {'content': '{\'query\': \'Miami Heat highest scorer 2006-2007 NBA season\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'url\': \'https://www.landofbasketball.com/stats_by_team/2006_2007_heat_rs.htm\', \'title\': \'2006-07 Miami Heat Player Stats - Regular Season\', \'content\': "2006-07 Miami Heat -. NBA Regular Season Stats ; Dwyane Wade · 51, 37.9 ; Shaquille O\'Neal · 40, 28.4 ; Jason Kapono · 67, 26.4 ; Jason Williams · 61, 30.6", \'score\': 0.8440111, \'raw_content\': None}], \'response_time\': 1.45}',
#        'source': 'WebSearchAgent',
#        'type': 'UserMessage'},
#       {'content': "Based on the search results, the Miami Heat player with the most points during the 2006-2007 NBA season was Dwyane Wade.\n\nNow, let's proceed to the next task.\n\n1. WebSearchAgent: Find the total rebounds for Dwyane Wade during the 2007-2008 and 2008-2009 seasons.",
#        'source': 'PlanningAgent',
#        'type': 'UserMessage'},
#       {'content': "{'query': 'Dwyane Wade total rebounds 2007-2008 NBA season', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.statmuse.com/nba/ask/dwyane-wade-2008-nba-stats', 'title': 'Dwyane Wade 2008 NBA Stats | StatMuse', 'content': 'Dwyane Wade averaged 24.6 points, 6.9 assists and 4.2 rebounds in 51 games in 2007-08. He was selected to play in his fourth All-Star game.', 'score': 0.93554133, 'raw_content': None}], 'response_time': 1.07}\n{'query': 'Dwyane Wade total rebounds 2008-2009 NBA season', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.statmuse.com/nba/ask/dwyane-wade-2008-2009-stats', 'title': 'Dwyane Wade 2008 2009 Stats | StatMuse', 'content': 'Dwyane Wade averaged 30.2 points, 7.5 assists and 5.0 rebounds in 79 games in 2008-09. He was selected to play in his fifth All-Star game.', 'score': 0.9255605, 'raw_content': None}], 'response_time': 1.82}",
#        'source': 'WebSearchAgent',
#        'type': 'UserMessage'},
#       {'content': [{'id': 'call_STqo4atdupQyxYGDn04xlhc4',
#          'arguments': '{"start":4.2,"end":5.0}',
#          'name': 'percentage_change_tool'}],
#        'thought': "Dwyane Wade averaged:\n\n- 4.2 rebounds in the 2007-2008 season over 51 games.\n- 5.0 rebounds in the 2008-2009 season over 79 games.\n\nNow, let's calculate the percentage change in his total rebounds between these seasons.",
#        'source': 'DataAnalystAgent',
#        'type': 'AssistantMessage'},
#       {'content': [{'content': '19.047619047619044',
#          'name': 'percentage_change_tool',
#          'call_id': 'call_STqo4atdupQyxYGDn04xlhc4',
#          'is_error': False}],
#        'type': 'FunctionExecutionResultMessage'}]}},
#    'message_buffer': [{'id': '5e275e21-c45a-4831-87c6-3e15d95451e1',
#      'source': 'PlanningAgent',
#      'models_usage': {'prompt_tokens': 947, 'completion_tokens': 113},
#      'metadata': {},
#      'created_at': datetime.datetime(2025, 8, 8, 14, 9, 43, 64761, tzinfo=datetime.timezone.utc),
#      'content': "We have gathered the necessary data:\n\n- Dwyane Wade, who was the Miami Heat player with the highest points during the 2006-2007 season, averaged 4.2 rebounds per game in the 2007-2008 season and 5.0 rebounds per game in the 2008-2009 season.\n\nThe Data Analyst Agent calculated that there was a 19.05% increase in Dwyane Wade's total rebounds from the 2007-2008 season to the 2008-2009 season.\n\nTERMINATE",
#      'type': 'TextMessage'},
#     {'id': 'fea1690f-358e-4793-b826-b63a44afe2e5',
#      'source': 'user',
#      'models_usage': None,
#      'metadata': {},
#      'created_at': datetime.datetime(2025, 8, 8, 14, 9, 43, 111123, tzinfo=datetime.timezone.utc),
#      'content': 'Who was the Miami Heat player with the highest point in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?',
#      'type': 'TextMessage'},
#     {'id': '0f42f932-c195-42e1-9d7a-34705ed9ce8e',
#      'source': 'PlanningAgent',
#      'models_usage': {'prompt_tokens': 1116, 'completion_tokens': 174},
#      'metadata': {},
#      'created_at': datetime.datetime(2025, 8, 8, 14, 9, 49, 355571, tzinfo=datetime.timezone.utc),
#      'content': "To address your inquiry, we have already completed the following tasks:\n\n1. Identified the Miami Heat player with the highest points during the 2006-2007 season - Dwyane Wade.\n2. Calculated the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons.\n\nHere's the summary:\n- **2006-2007 Season:** Dwyane Wade was the player with the highest points for the Miami Heat.\n- **Total Rebounds:** \n  - 2007-2008 Season: 4.2 rebounds per game.\n  - 2008-2009 Season: 5.0 rebounds per game.\n  \nThe percentage increase in his rebounds from the 2007-2008 season to the 2008-2009 season was 19.05%.\n\nTERMINATE",
#      'type': 'TextMessage'}]},
#   'SelectorGroupChatManager': {'type': 'SelectorManagerState',
#    'version': '1.0.0',
#    'message_thread': [{'id': '7d79691e-a4b9-4fb0-901e-3132f2cc9828',
#      'source': 'user',
#      'models_usage': None,
#      'metadata': {},
#      'created_at': datetime.datetime(2025, 8, 8, 14, 9, 14, 425379, tzinfo=datetime.timezone.utc),
#      'content': 'Who was the Miami Heat player with the highest point in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?',
#      'type': 'TextMessage'},
#     {'id': '8800c856-32aa-4622-8425-e35b98ee75d0',
#      'source': 'PlanningAgent',
#      'models_usage': {'prompt_tokens': 161, 'completion_tokens': 187},
#      'metadata': {},
#      'created_at': datetime.datetime(2025, 8, 8, 14, 9, 21, 410874, tzinfo=datetime.timezone.utc),
#      'content': "To provide a comprehensive response to your inquiry, we need to fulfill these tasks:\n\n1. Identify the Miami Heat player with the highest points during the 2006-2007 NBA season.\n2. Calculate the difference in total rebounds for this player between the 2007-2008 and 2008-2009 seasons. Then, compute the percentage change based on these figures.\n\nLet's start by assigning tasks. \n\n1. WebSearchAgent: Research which Miami Heat player had the most points during the 2006-2007 season.\n2. WebSearchAgent: Find the total rebounds for this player during the 2007-2008 and 2008-2009 seasons.\n3. DataAnalystAgent: Calculate the percentage change in total rebounds between the 2007-2008 and 2008-2009 seasons based on the retrieved data.\n\nOnce these tasks have been completed, we'll summarize the findings.",
#      'type': 'TextMessage'},
#     {'id': 'b43ea1e8-5b6c-4b63-b864-22bf62322ed0',
#      'source': 'WebSearchAgent',
#      'models_usage': {'prompt_tokens': 352, 'completion_tokens': 25},
#      'metadata': {},
#      'created_at': datetime.datetime(2025, 8, 8, 14, 9, 24, 336834, tzinfo=datetime.timezone.utc),
#      'content': [{'id': 'call_Z8m1fRkulOowPAezRmOl4Hc3',
#        'arguments': '{"query":"Miami Heat highest scorer 2006-2007 NBA season"}',
#        'name': 'search_web'}],
#      'type': 'ToolCallRequestEvent'},
#     {'id': '6f4ca2f6-7c72-498f-aa81-adcbafdb8f0d',
#      'source': 'WebSearchAgent',
#      'models_usage': None,
#      'metadata': {},
#      'created_at': datetime.datetime(2025, 8, 8, 14, 9, 26, 726785, tzinfo=datetime.timezone.utc),
#      'content': [{'content': '{\'query\': \'Miami Heat highest scorer 2006-2007 NBA season\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'url\': \'https://www.landofbasketball.com/stats_by_team/2006_2007_heat_rs.htm\', \'title\': \'2006-07 Miami Heat Player Stats - Regular Season\', \'content\': "2006-07 Miami Heat -. NBA Regular Season Stats ; Dwyane Wade · 51, 37.9 ; Shaquille O\'Neal · 40, 28.4 ; Jason Kapono · 67, 26.4 ; Jason Williams · 61, 30.6", \'score\': 0.8440111, \'raw_content\': None}], \'response_time\': 1.45}',
#        'name': 'search_web',
#        'call_id': 'call_Z8m1fRkulOowPAezRmOl4Hc3',
#        'is_error': False}],
#      'type': 'ToolCallExecutionEvent'},
#     {'id': 'ce3cbcfe-96fb-4e00-9220-3c1c6c7e5d0b',
#      'source': 'WebSearchAgent',
#      'models_usage': None,
#      'metadata': {},
#      'created_at': datetime.datetime(2025, 8, 8, 14, 9, 26, 726785, tzinfo=datetime.timezone.utc),
#      'content': '{\'query\': \'Miami Heat highest scorer 2006-2007 NBA season\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'url\': \'https://www.landofbasketball.com/stats_by_team/2006_2007_heat_rs.htm\', \'title\': \'2006-07 Miami Heat Player Stats - Regular Season\', \'content\': "2006-07 Miami Heat -. NBA Regular Season Stats ; Dwyane Wade · 51, 37.9 ; Shaquille O\'Neal · 40, 28.4 ; Jason Kapono · 67, 26.4 ; Jason Williams · 61, 30.6", \'score\': 0.8440111, \'raw_content\': None}], \'response_time\': 1.45}',
#      'type': 'ToolCallSummaryMessage',
#      'tool_calls': [{'id': 'call_Z8m1fRkulOowPAezRmOl4Hc3',
#        'arguments': '{"query":"Miami Heat highest scorer 2006-2007 NBA season"}',
#        'name': 'search_web'}],
#      'results': [{'content': '{\'query\': \'Miami Heat highest scorer 2006-2007 NBA season\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'url\': \'https://www.landofbasketball.com/stats_by_team/2006_2007_heat_rs.htm\', \'title\': \'2006-07 Miami Heat Player Stats - Regular Season\', \'content\': "2006-07 Miami Heat -. NBA Regular Season Stats ; Dwyane Wade · 51, 37.9 ; Shaquille O\'Neal · 40, 28.4 ; Jason Kapono · 67, 26.4 ; Jason Williams · 61, 30.6", \'score\': 0.8440111, \'raw_content\': None}], \'response_time\': 1.45}',
#        'name': 'search_web',
#        'call_id': 'call_Z8m1fRkulOowPAezRmOl4Hc3',
#        'is_error': False}]},
#     {'id': 'cce2f037-cf15-472b-a1fc-cc958f30e51e',
#      'source': 'PlanningAgent',
#      'models_usage': {'prompt_tokens': 531, 'completion_tokens': 71},
#      'metadata': {},
#      'created_at': datetime.datetime(2025, 8, 8, 14, 9, 29, 279716, tzinfo=datetime.timezone.utc),
#      'content': "Based on the search results, the Miami Heat player with the most points during the 2006-2007 NBA season was Dwyane Wade.\n\nNow, let's proceed to the next task.\n\n1. WebSearchAgent: Find the total rebounds for Dwyane Wade during the 2007-2008 and 2008-2009 seasons.",
#      'type': 'TextMessage'},
#     {'id': '4060f169-31cf-4ab7-ad59-f30faf8f5a52',
#      'source': 'WebSearchAgent',
#      'models_usage': {'prompt_tokens': 634, 'completion_tokens': 70},
#      'metadata': {},
#      'created_at': datetime.datetime(2025, 8, 8, 14, 9, 32, 419655, tzinfo=datetime.timezone.utc),
#      'content': [{'id': 'call_P8P28AGnatYN6zaVi8qPK0Sj',
#        'arguments': '{"query": "Dwyane Wade total rebounds 2007-2008 NBA season"}',
#        'name': 'search_web'},
#       {'id': 'call_kl2cX0IRHVkCTNtW99KCSjJe',
#        'arguments': '{"query": "Dwyane Wade total rebounds 2008-2009 NBA season"}',
#        'name': 'search_web'}],
#      'type': 'ToolCallRequestEvent'},
#     {'id': '50c3b803-02ed-4bdf-a11f-1254c6039e66',
#      'source': 'WebSearchAgent',
#      'models_usage': None,
#      'metadata': {},
#      'created_at': datetime.datetime(2025, 8, 8, 14, 9, 35, 79904, tzinfo=datetime.timezone.utc),
#      'content': [{'content': "{'query': 'Dwyane Wade total rebounds 2007-2008 NBA season', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.statmuse.com/nba/ask/dwyane-wade-2008-nba-stats', 'title': 'Dwyane Wade 2008 NBA Stats | StatMuse', 'content': 'Dwyane Wade averaged 24.6 points, 6.9 assists and 4.2 rebounds in 51 games in 2007-08. He was selected to play in his fourth All-Star game.', 'score': 0.93554133, 'raw_content': None}], 'response_time': 1.07}",
#        'name': 'search_web',
#        'call_id': 'call_P8P28AGnatYN6zaVi8qPK0Sj',
#        'is_error': False},
#       {'content': "{'query': 'Dwyane Wade total rebounds 2008-2009 NBA season', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.statmuse.com/nba/ask/dwyane-wade-2008-2009-stats', 'title': 'Dwyane Wade 2008 2009 Stats | StatMuse', 'content': 'Dwyane Wade averaged 30.2 points, 7.5 assists and 5.0 rebounds in 79 games in 2008-09. He was selected to play in his fifth All-Star game.', 'score': 0.9255605, 'raw_content': None}], 'response_time': 1.82}",
#        'name': 'search_web',
#        'call_id': 'call_kl2cX0IRHVkCTNtW99KCSjJe',
#        'is_error': False}],
#      'type': 'ToolCallExecutionEvent'},
#     {'id': '3975ea22-a882-42bb-b674-958111dd1347',
#      'source': 'WebSearchAgent',
#      'models_usage': None,
#      'metadata': {},
#      'created_at': datetime.datetime(2025, 8, 8, 14, 9, 35, 81681, tzinfo=datetime.timezone.utc),
#      'content': "{'query': 'Dwyane Wade total rebounds 2007-2008 NBA season', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.statmuse.com/nba/ask/dwyane-wade-2008-nba-stats', 'title': 'Dwyane Wade 2008 NBA Stats | StatMuse', 'content': 'Dwyane Wade averaged 24.6 points, 6.9 assists and 4.2 rebounds in 51 games in 2007-08. He was selected to play in his fourth All-Star game.', 'score': 0.93554133, 'raw_content': None}], 'response_time': 1.07}\n{'query': 'Dwyane Wade total rebounds 2008-2009 NBA season', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.statmuse.com/nba/ask/dwyane-wade-2008-2009-stats', 'title': 'Dwyane Wade 2008 2009 Stats | StatMuse', 'content': 'Dwyane Wade averaged 30.2 points, 7.5 assists and 5.0 rebounds in 79 games in 2008-09. He was selected to play in his fifth All-Star game.', 'score': 0.9255605, 'raw_content': None}], 'response_time': 1.82}",
#      'type': 'ToolCallSummaryMessage',
#      'tool_calls': [{'id': 'call_P8P28AGnatYN6zaVi8qPK0Sj',
#        'arguments': '{"query": "Dwyane Wade total rebounds 2007-2008 NBA season"}',
#        'name': 'search_web'},
#       {'id': 'call_kl2cX0IRHVkCTNtW99KCSjJe',
#        'arguments': '{"query": "Dwyane Wade total rebounds 2008-2009 NBA season"}',
#        'name': 'search_web'}],
#      'results': [{'content': "{'query': 'Dwyane Wade total rebounds 2007-2008 NBA season', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.statmuse.com/nba/ask/dwyane-wade-2008-nba-stats', 'title': 'Dwyane Wade 2008 NBA Stats | StatMuse', 'content': 'Dwyane Wade averaged 24.6 points, 6.9 assists and 4.2 rebounds in 51 games in 2007-08. He was selected to play in his fourth All-Star game.', 'score': 0.93554133, 'raw_content': None}], 'response_time': 1.07}",
#        'name': 'search_web',
#        'call_id': 'call_P8P28AGnatYN6zaVi8qPK0Sj',
#        'is_error': False},
#       {'content': "{'query': 'Dwyane Wade total rebounds 2008-2009 NBA season', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.statmuse.com/nba/ask/dwyane-wade-2008-2009-stats', 'title': 'Dwyane Wade 2008 2009 Stats | StatMuse', 'content': 'Dwyane Wade averaged 30.2 points, 7.5 assists and 5.0 rebounds in 79 games in 2008-09. He was selected to play in his fifth All-Star game.', 'score': 0.9255605, 'raw_content': None}], 'response_time': 1.82}",
#        'name': 'search_web',
#        'call_id': 'call_kl2cX0IRHVkCTNtW99KCSjJe',
#        'is_error': False}]},
#     {'id': '1b42da0d-d4d2-4db2-a769-7fd7e5239e3e',
#      'source': 'DataAnalystAgent',
#      'models_usage': None,
#      'metadata': {},
#      'created_at': datetime.datetime(2025, 8, 8, 14, 9, 39, 208319, tzinfo=datetime.timezone.utc),
#      'content': "Dwyane Wade averaged:\n\n- 4.2 rebounds in the 2007-2008 season over 51 games.\n- 5.0 rebounds in the 2008-2009 season over 79 games.\n\nNow, let's calculate the percentage change in his total rebounds between these seasons.",
#      'type': 'ThoughtEvent'},
#     {'id': 'dc58264a-17bd-4867-92b3-3506f07755a3',
#      'source': 'DataAnalystAgent',
#      'models_usage': {'prompt_tokens': 926, 'completion_tokens': 86},
#      'metadata': {},
#      'created_at': datetime.datetime(2025, 8, 8, 14, 9, 39, 208319, tzinfo=datetime.timezone.utc),
#      'content': [{'id': 'call_STqo4atdupQyxYGDn04xlhc4',
#        'arguments': '{"start":4.2,"end":5.0}',
#        'name': 'percentage_change_tool'}],
#      'type': 'ToolCallRequestEvent'},
#     {'id': '3b9f2d20-4cf4-44fa-8b58-5621a4b7f35b',
#      'source': 'DataAnalystAgent',
#      'models_usage': None,
#      'metadata': {},
#      'created_at': datetime.datetime(2025, 8, 8, 14, 9, 39, 214077, tzinfo=datetime.timezone.utc),
#      'content': [{'content': '19.047619047619044',
#        'name': 'percentage_change_tool',
#        'call_id': 'call_STqo4atdupQyxYGDn04xlhc4',
#        'is_error': False}],
#      'type': 'ToolCallExecutionEvent'},
#     {'id': '725cd0ec-7b63-4dda-8a44-2ada7de51579',
#      'source': 'DataAnalystAgent',
#      'models_usage': None,
#      'metadata': {},
#      'created_at': datetime.datetime(2025, 8, 8, 14, 9, 39, 214588, tzinfo=datetime.timezone.utc),
#      'content': '19.047619047619044',
#      'type': 'ToolCallSummaryMessage',
#      'tool_calls': [{'id': 'call_STqo4atdupQyxYGDn04xlhc4',
#        'arguments': '{"start":4.2,"end":5.0}',
#        'name': 'percentage_change_tool'}],
#      'results': [{'content': '19.047619047619044',
#        'name': 'percentage_change_tool',
#        'call_id': 'call_STqo4atdupQyxYGDn04xlhc4',
#        'is_error': False}]},
#     {'id': '5e275e21-c45a-4831-87c6-3e15d95451e1',
#      'source': 'PlanningAgent',
#      'models_usage': {'prompt_tokens': 947, 'completion_tokens': 113},
#      'metadata': {},
#      'created_at': datetime.datetime(2025, 8, 8, 14, 9, 43, 64761, tzinfo=datetime.timezone.utc),
#      'content': "We have gathered the necessary data:\n\n- Dwyane Wade, who was the Miami Heat player with the highest points during the 2006-2007 season, averaged 4.2 rebounds per game in the 2007-2008 season and 5.0 rebounds per game in the 2008-2009 season.\n\nThe Data Analyst Agent calculated that there was a 19.05% increase in Dwyane Wade's total rebounds from the 2007-2008 season to the 2008-2009 season.\n\nTERMINATE",
#      'type': 'TextMessage'},
#     {'id': 'fea1690f-358e-4793-b826-b63a44afe2e5',
#      'source': 'user',
#      'models_usage': None,
#      'metadata': {},
#      'created_at': datetime.datetime(2025, 8, 8, 14, 9, 43, 111123, tzinfo=datetime.timezone.utc),
#      'content': 'Who was the Miami Heat player with the highest point in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?',
#      'type': 'TextMessage'},
#     {'id': '0f42f932-c195-42e1-9d7a-34705ed9ce8e',
#      'source': 'PlanningAgent',
#      'models_usage': {'prompt_tokens': 1116, 'completion_tokens': 174},
#      'metadata': {},
#      'created_at': datetime.datetime(2025, 8, 8, 14, 9, 49, 355571, tzinfo=datetime.timezone.utc),
#      'content': "To address your inquiry, we have already completed the following tasks:\n\n1. Identified the Miami Heat player with the highest points during the 2006-2007 season - Dwyane Wade.\n2. Calculated the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons.\n\nHere's the summary:\n- **2006-2007 Season:** Dwyane Wade was the player with the highest points for the Miami Heat.\n- **Total Rebounds:** \n  - 2007-2008 Season: 4.2 rebounds per game.\n  - 2008-2009 Season: 5.0 rebounds per game.\n  \nThe percentage increase in his rebounds from the 2007-2008 season to the 2008-2009 season was 19.05%.\n\nTERMINATE",
#      'type': 'TextMessage'}],
#    'current_turn': 0,
#    'previous_speaker': 'PlanningAgent'}}}

# %% [markdown]
# # custom selector function

# %%
from autogen_agentchat.messages import BaseAgentEvent, BaseChatMessage
from typing import Sequence

def my_selector_fun(messages: Sequence[BaseAgentEvent | BaseChatMessage]):

    if messages[-1].source != planning_agent.name:
        return planning_agent.name
    return None


selector_team = SelectorGroupChat(
    participants=[planning_agent, web_search_agent, data_analyst_agent],
    model_client=model_client,
    termination_condition=combined_termination,
    selector_prompt=selector_prompt,
    allow_repeated_speaker=True,
    selector_func=my_selector_fun)

# %%
# With real web search
task = "Who was the Miami Heat player with the highest point in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?"

from autogen_agentchat.ui import Console

await Console(selector_team.run_stream(task=task))
# Out:
# ---------- TextMessage (user) ----------
# Who was the Miami Heat player with the highest point in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?
# ---------- TextMessage (PlanningAgent) ----------
# To address your query effectively, we have carried out the necessary tasks and obtained the following information:
#
# 1. **Highest Scorer for the Miami Heat in the 2006-2007 Season:**
#    - The player with the most points was Dwyane Wade.
#
# 2. **Change in Total Rebounds:**
#    - For the 2007-2008 NBA season, Dwyane Wade averaged 4.2 rebounds per game.
#    - For the 2008-2009 NBA season, his average was 5.0 rebounds per game.
#    - The calculated percentage increase in his total rebounds from the 2007-2008 season to the 2008-2009 season is 19.05%.
#
# This summarizes the information you asked for:
#
# - **Player:** Dwyane Wade
# - **Seasons:** 2007-2008 to 2008-2009
# - **Percentage Change in Rebounds:** 19.05% increase
#
# TERMINATE
# TaskResult(messages=[TextMessage(id='83320fb1-7a64-4203-86cc-454c1c7b587a', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 8, 14, 9, 49, 479409, tzinfo=datetime.timezone.utc), content='Who was the Miami Heat player with the highest point in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?', type='TextMessage'), TextMessage(id='227304f8-4273-4a83-b4e1-d723fd0ecbab', source='PlanningAgent', models_usage=RequestUsage(prompt_tokens=1346, completion_tokens=202), metadata={}, created_at=datetime.datetime(2025, 8, 8, 14, 9, 53, 784727, tzinfo=datetime.timezone.utc), content='To address your query effectively, we have carried out the necessary tasks and obtained the following information:\n\n1. **Highest Scorer for the Miami Heat in the 2006-2007 Season:** \n   - The player with the most points was Dwyane Wade.\n\n2. **Change in Total Rebounds:**\n   - For the 2007-2008 NBA season, Dwyane Wade averaged 4.2 rebounds per game.\n   - For the 2008-2009 NBA season, his average was 5.0 rebounds per game.\n   - The calculated percentage increase in his total rebounds from the 2007-2008 season to the 2008-2009 season is 19.05%.\n\nThis summarizes the information you asked for:\n\n- **Player:** Dwyane Wade\n- **Seasons:** 2007-2008 to 2008-2009\n- **Percentage Change in Rebounds:** 19.05% increase \n\nTERMINATE', type='TextMessage')], stop_reason="Text 'TERMINATE' mentioned")

# %%
await selector_team.reset()

# %%
# If Data analyst agent is not selected after web search agent
task = "Who was the Miami Heat player with the highest point in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?"

from autogen_agentchat.messages import BaseAgentEvent, BaseChatMessage
from typing import Sequence

def my_selector_fun(messages: Sequence[BaseAgentEvent | BaseChatMessage]):

    if messages[-1].source != web_search_agent.name:
        return data_analyst_agent.name
    return None


selector_team = SelectorGroupChat(
    participants=[planning_agent, web_search_agent, data_analyst_agent],
    model_client=model_client,
    termination_condition=combined_termination,
    selector_prompt=selector_prompt,
    allow_repeated_speaker=False,
    selector_func=my_selector_fun)


from autogen_agentchat.ui import Console

await Console(selector_team.run_stream(task=task))
# Out:
# ---------- TextMessage (user) ----------
# Who was the Miami Heat player with the highest point in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?
# ---------- TextMessage (DataAnalystAgent) ----------
# Please provide me with the data for the Miami Heat player's statistics for the 2006-2007 season as well as the total rebounds for the 2007-2008 and 2008-2009 seasons.
# ---------- TextMessage (DataAnalystAgent) ----------
# Please provide me with the data for the Miami Heat player's statistics for the 2006-2007 season as well as the total rebounds for the 2007-2008 and 2008-2009 seasons.
# ---------- TextMessage (DataAnalystAgent) ----------
# Please provide the data for the Miami Heat players' points for the 2006-2007 season, along with their total rebounds for the 2007-2008 and 2008-2009 seasons.
# ---------- TextMessage (DataAnalystAgent) ----------
# Please provide the data for the Miami Heat players' points for the 2006-2007 season, along with their total rebounds for the 2007-2008 and 2008-2009 seasons.
# ---------- TextMessage (DataAnalystAgent) ----------
# Please provide the data for the Miami Heat players' point scores for the 2006-2007 season and their total rebounds for the 2007-2008 and 2008-2009 seasons.
# ---------- TextMessage (DataAnalystAgent) ----------
# Please provide the data for the Miami Heat players' point scores for the 2006-2007 season and their total rebounds for the 2007-2008 and 2008-2009 seasons.
# ---------- TextMessage (DataAnalystAgent) ----------
# Please provide data on the Miami Heat players' points scored for the 2006-2007 season along with their total rebounds for the 2007-2008 and 2008-2009 seasons.
# ---------- TextMessage (DataAnalystAgent) ----------
# Please provide data on the Miami Heat players' points scored for the 2006-2007 season along with their total rebounds for the 2007-2008 and 2008-2009 seasons.
# ---------- TextMessage (DataAnalystAgent) ----------
# Please provide the data for the Miami Heat players' points scored in the 2006-2007 season and their total rebounds for the 2007-2008 and 2008-2009 seasons.
# ---------- TextMessage (DataAnalystAgent) ----------
# Please provide the data for the Miami Heat players' points scored in the 2006-2007 season and their total rebounds for the 2007-2008 and 2008-2009 seasons.
# ---------- TextMessage (DataAnalystAgent) ----------
# Please provide the data for the Miami Heat players' points for the 2006-2007 season, along with their total rebounds for the 2007-2008 and 2008-2009 seasons.
# ---------- TextMessage (DataAnalystAgent) ----------
# Please provide the data for the Miami Heat players' points for the 2006-2007 season, along with their total rebounds for the 2007-2008 and 2008-2009 seasons.
# ---------- TextMessage (DataAnalystAgent) ----------
# Please provide the data for the Miami Heat players' point scores for the 2006-2007 season and their total rebounds for the 2007-2008 and 2008-2009 seasons.
# ---------- TextMessage (DataAnalystAgent) ----------
# Please provide the data for the Miami Heat players' point scores for the 2006-2007 season and their total rebounds for the 2007-2008 and 2008-2009 seasons.
# ---------- TextMessage (DataAnalystAgent) ----------
# Please provide data on the Miami Heat players' points scored for the 2006-2007 season along with their total rebounds for the 2007-2008 and 2008-2009 seasons.
# ---------- TextMessage (DataAnalystAgent) ----------
# Please provide data on the Miami Heat players' points scored for the 2006-2007 season along with their total rebounds for the 2007-2008 and 2008-2009 seasons.
# ---------- TextMessage (DataAnalystAgent) ----------
# Please provide the data for the Miami Heat players' points scored in the 2006-2007 season and their total rebounds for the 2007-2008 and 2008-2009 seasons.
# ---------- TextMessage (DataAnalystAgent) ----------
# Please provide the data for the Miami Heat players' points scored in the 2006-2007 season and their total rebounds for the 2007-2008 and 2008-2009 seasons.
# ---------- TextMessage (DataAnalystAgent) ----------
# Please provide the data for the Miami Heat players' points for the 2006-2007 season, along with their total rebounds for the 2007-2008 and 2008-2009 seasons.
# TaskResult(messages=[TextMessage(id='c6ce8bb3-825c-4629-ba34-9b2e6f76f4a1', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 8, 14, 9, 53, 839488, tzinfo=datetime.timezone.utc), content='Who was the Miami Heat player with the highest point in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?', type='TextMessage'), TextMessage(id='b71a74a8-89f0-45f0-8285-8f48c69ffa84', source='DataAnalystAgent', models_usage=RequestUsage(prompt_tokens=150, completion_tokens=45), metadata={}, created_at=datetime.datetime(2025, 8, 8, 14, 9, 56, 482034, tzinfo=datetime.timezone.utc), content="Please provide me with the data for the Miami Heat player's statistics for the 2006-2007 season as well as the total rebounds for the 2007-2008 and 2008-2009 seasons.", type='TextMessage'), TextMessage(id='d3dd1a56-49ad-4ccd-afe7-8113494a21e9', source='DataAnalystAgent', models_usage=RequestUsage(prompt_tokens=198, completion_tokens=45), metadata={}, created_at=datetime.datetime(2025, 8, 8, 14, 9, 58, 123102, tzinfo=datetime.timezone.utc), content="Please provide me with the data for the Miami Heat player's statistics for the 2006-2007 season as well as the total rebounds for the 2007-2008 and 2008-2009 seasons.", type='TextMessage'), TextMessage(id='d0b9de87-14aa-4e2c-a9b2-3d50fac05053', source='DataAnalystAgent', models_usage=RequestUsage(prompt_tokens=246, completion_tokens=44), metadata={}, created_at=datetime.datetime(2025, 8, 8, 14, 10, 0, 263195, tzinfo=datetime.timezone.utc), content="Please provide the data for the Miami Heat players' points for the 2006-2007 season, along with their total rebounds for the 2007-2008 and 2008-2009 seasons.", type='TextMessage'), TextMessage(id='92599b91-6c00-498c-b17f-639dd9374f56', source='DataAnalystAgent', models_usage=RequestUsage(prompt_tokens=293, completion_tokens=44), metadata={}, created_at=datetime.datetime(2025, 8, 8, 14, 10, 2, 458834, tzinfo=datetime.timezone.utc), content="Please provide the data for the Miami Heat players' points for the 2006-2007 season, along with their total rebounds for the 2007-2008 and 2008-2009 seasons.", type='TextMessage'), TextMessage(id='afb7e106-d6ef-4b86-ab7e-496abcc13703', source='DataAnalystAgent', models_usage=RequestUsage(prompt_tokens=340, completion_tokens=43), metadata={}, created_at=datetime.datetime(2025, 8, 8, 14, 10, 4, 730762, tzinfo=datetime.timezone.utc), content="Please provide the data for the Miami Heat players' point scores for the 2006-2007 season and their total rebounds for the 2007-2008 and 2008-2009 seasons.", type='TextMessage'), TextMessage(id='577ecf94-1d4b-4ed1-a11f-a03266b1ef84', source='DataAnalystAgent', models_usage=RequestUsage(prompt_tokens=386, completion_tokens=43), metadata={}, created_at=datetime.datetime(2025, 8, 8, 14, 10, 6, 578158, tzinfo=datetime.timezone.utc), content="Please provide the data for the Miami Heat players' point scores for the 2006-2007 season and their total rebounds for the 2007-2008 and 2008-2009 seasons.", type='TextMessage'), TextMessage(id='e75194c2-4afe-40c5-8c70-ad63fa641c14', source='DataAnalystAgent', models_usage=RequestUsage(prompt_tokens=432, completion_tokens=43), metadata={}, created_at=datetime.datetime(2025, 8, 8, 14, 10, 8, 327169, tzinfo=datetime.timezone.utc), content="Please provide data on the Miami Heat players' points scored for the 2006-2007 season along with their total rebounds for the 2007-2008 and 2008-2009 seasons.", type='TextMessage'), TextMessage(id='2e73e68f-d9fd-4a6f-a6f3-a087cda016c4', source='DataAnalystAgent', models_usage=RequestUsage(prompt_tokens=478, completion_tokens=43), metadata={}, created_at=datetime.datetime(2025, 8, 8, 14, 10, 9, 726509, tzinfo=datetime.timezone.utc), content="Please provide data on the Miami Heat players' points scored for the 2006-2007 season along with their total rebounds for the 2007-2008 and 2008-2009 seasons.", type='TextMessage'), TextMe ...

# %%
from typing import List

# %%
def candidate_func(messages: Sequence[BaseAgentEvent | BaseChatMessage]) -> List[str]:
    # keep planning_agent first one to plan out the tasks
    if messages[-1].source == "user":
        return [planning_agent.name]

    # if previous agent is planning_agent and if it explicitely asks for web_search_agent
    # or data_analyst_agent or both (in-case of re-planning or re-assignment of tasks)
    # then return those specific agents
    last_message = messages[-1]
    if last_message.source == planning_agent.name:
        participants = []
        if web_search_agent.name in last_message.to_text():
            participants.append(web_search_agent.name)
        if data_analyst_agent.name in last_message.to_text():
            participants.append(data_analyst_agent.name)
        if participants:
            return participants  # SelectorGroupChat will select from the remaining two agents.

    # we can assume that the task is finished once the web_search_agent
    # and data_analyst_agent have took their turns, thus we send
    # in planning_agent to terminate the chat
    previous_set_of_agents = set(message.source for message in messages)
    if web_search_agent.name in previous_set_of_agents and data_analyst_agent.name in previous_set_of_agents:
        return [planning_agent.name]

    # if no-conditions are met then return all the agents
    return [planning_agent.name, web_search_agent.name, data_analyst_agent.name]

# %%
from autogen_agentchat.agents import UserProxyAgent

user_proxy_agent = UserProxyAgent("UserProxyAgent", description="A proxy for the user to approve or disapprove tasks.")

text_mention_termination = TextMentionTermination("TERMINATE")
max_messages_termination = MaxMessageTermination(max_messages=10)
termination = text_mention_termination | max_messages_termination


def selector_func_with_user_proxy(messages: Sequence[BaseAgentEvent | BaseChatMessage]) -> str | None:
    if messages[-1].source != planning_agent.name and messages[-1].source != user_proxy_agent.name:
        # Planning agent should be the first to engage when given a new task, or check progress.
        return planning_agent.name
    

    if messages[-1].source == planning_agent.name:
        if messages[-2].source == user_proxy_agent.name and "APPROVE" in messages[-1].content.upper():  # type: ignore
            # User has approved the plan, proceed to the next agent.
            return None
        # Use the user proxy agent to get the user's approval to proceed.
        return user_proxy_agent.name
    

    if messages[-1].source == user_proxy_agent.name:
        # If the user does not approve, return to the planning agent.
        if "APPROVE" not in messages[-1].content.upper():  # type: ignore
            return planning_agent.name
        

    return None


# Reset the previous agents and run the chat again with the user proxy agent and selector function.
# await sele.reset()
team = SelectorGroupChat(
    [planning_agent, web_search_agent, data_analyst_agent, user_proxy_agent],
    model_client=model_client,
    termination_condition=termination,
    selector_prompt=selector_prompt,
    selector_func=selector_func_with_user_proxy,
    allow_repeated_speaker=True,
)

await Console(team.run_stream(task=task))
# Out:
# ---------- TextMessage (user) ----------
# Who was the Miami Heat player with the highest point in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?
# ---------- TextMessage (PlanningAgent) ----------
# To answer these questions, we need to gather some specific historical data related to the Miami Heat player's performance stats for the specified seasons. Here's how we will break down the tasks:
#
# 1. WebSearchAgent: Identify the Miami Heat player with the highest points in the 2006-2007 season.
# 2. WebSearchAgent: Find the total rebounds for the identified player in the 2007-2008 and 2008-2009 seasons.
# 3. DataAnalystAgent: Calculate the percentage change in the player's total rebounds between the 2007-2008 and 2008-2009 seasons.
#
# Let's proceed with these tasks.
# ---------- TextMessage (UserProxyAgent) ----------
# APPROVE
# ---------- ToolCallRequestEvent (WebSearchAgent) ----------
# [FunctionCall(id='call_3KfGOqZqAaxDhVx3aiRAuo5f', arguments='{"query":"Miami Heat player with highest points in 2006-2007 season"}', name='search_web')]
# ---------- ToolCallExecutionEvent (WebSearchAgent) ----------
# [FunctionExecutionResult(content="{'query': 'Miami Heat player with highest points in 2006-2007 season', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.landofbasketball.com/stats_by_team/2006_2007_heat_rs.htm', 'title': '2006-07 Miami Heat Player Stats - Regular Season', 'content': '**Season:** Stats / Season Series Stats / Playoff Series # 2006-07 Miami Heat Player Stats - Regular Season ## Stats per game recorded by the 2006-2007 Heat players in the Regular Season, including games, points, rebounds, assists, steals, blocks and shooting details. ### 2006-07 Miami Heat - NBA Regular Season Stats | Jason Kapono | 67 | 26.4 | 10.9 | 0.4 | 2.3 | 2.7 | 1.2 | 0.6 | 0.0 | 1.0 | 2.0 | | Jason Williams | 61 | 30.6 | 10.9 | 0.3 | 2.0 | 2.3 | 5.3 | 1.0 | 0.0 | 1.6 | 1.1 | | Jason Kapono | 10.9 |  | 4.1 | 8.4 | .494 | 1.6 | 3.1 | .514 | 1.0 | 1.1 | .892 |', 'score': 0.9441409, 'raw_content': None}], 'response_time': 1.23}", name='search_web', call_id='call_3KfGOqZqAaxDhVx3aiRAuo5f', is_error=False)]
# ---------- ToolCallSummaryMessage (WebSearchAgent) ----------
# {'query': 'Miami Heat player with highest points in 2006-2007 season', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.landofbasketball.com/stats_by_team/2006_2007_heat_rs.htm', 'title': '2006-07 Miami Heat Player Stats - Regular Season', 'content': '**Season:** Stats / Season Series Stats / Playoff Series # 2006-07 Miami Heat Player Stats - Regular Season ## Stats per game recorded by the 2006-2007 Heat players in the Regular Season, including games, points, rebounds, assists, steals, blocks and shooting details. ### 2006-07 Miami Heat - NBA Regular Season Stats | Jason Kapono | 67 | 26.4 | 10.9 | 0.4 | 2.3 | 2.7 | 1.2 | 0.6 | 0.0 | 1.0 | 2.0 | | Jason Williams | 61 | 30.6 | 10.9 | 0.3 | 2.0 | 2.3 | 5.3 | 1.0 | 0.0 | 1.6 | 1.1 | | Jason Kapono | 10.9 |  | 4.1 | 8.4 | .494 | 1.6 | 3.1 | .514 | 1.0 | 1.1 | .892 |', 'score': 0.9441409, 'raw_content': None}], 'response_time': 1.23}
# ---------- TextMessage (PlanningAgent) ----------
# 1. WebSearchAgent: Retrieve specific details of the Miami Heat player with the highest points in the 2006-2007 season from the search result.
#
# Once we have the name of the player, we will proceed with the next tasks.
# ---------- TextMessage (UserProxyAgent) ----------
# APPROVED
# ---------- ThoughtEvent (WebSearchAgent) ----------
# The search result indicates that the Miami Heat player with the highest points in the 2006-2007 season was Jason Kapono, averaging 10.9 points per game.
#
# Now, let's find the total rebounds for Jason Kapono in the 2007-2008 and 2008-2009 seasons.
# ---------- ToolCallRequestEvent (WebSearchAgent) ----------
# [FunctionCall(id='call_9kyRo24q3VaMaPnRMws7iyyG', arguments='{"query": "Jason Kapono total rebounds 2007-2008 season"}', name='search_web'), FunctionCall(id='call_IxZGWgmnnPwcWXgLns4UiZQY', arguments='{"query": "Jason Kapono total rebounds 2008-2009 season"}', name='search_web')]
# ---------- ToolCallExecutionEvent (WebSearchAgent) ----------
# [FunctionExecutionResult(content="{'query': 'Jason Kapono total rebounds 2007-2008 season', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.landofbasketball.com/nba_players_stats/jason_kapono_tot.htm', 'title': 'Jason Kapono Stats: NBA Career Totals by Year', 'content': 'Jason Kapono totals in the NBA, both in the Regular Season and in the Playoffs, including points, rebounds, assists, steals, blocks and other categories.', 'score': 0.5172057, 'raw_content': None}], 'response_time': 1.33}", name='search_web', call_id='call_9kyRo24q3VaMaPnRMws7iyyG', is_error=False), FunctionExecutionResult(content="{'query': 'Jason Kapono total rebounds 2008-2009 season', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.landofbasketball.com/nba_players_game_logs/2009/jason_kapono.htm', 'title': 'Jason Kapono 2008-09 Basic Game Log - NBA Players Stats', 'content': 'Game by game statistics of Jason Kapono in the 2009 NBA Season and Playoffs. His Basic numbers including points, rebounds, assists, steals and blocks.', 'score': 0.74961954, 'raw_content': None}], 'response_time': 1.47}", name='search_web', call_id='call_IxZGWgmnnPwcWXgLns4UiZQY', is_error=False)]
# ---------- ToolCallSummaryMessage (WebSearchAgent) ----------
# {'query': 'Jason Kapono total rebounds 2007-2008 season', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.landofbasketball.com/nba_players_stats/jason_kapono_tot.htm', 'title': 'Jason Kapono Stats: NBA Career Totals by Year', 'content': 'Jason Kapono totals in the NBA, both in the Regular Season and in the Playoffs, including points, rebounds, assists, steals, blocks and other categories.', 'score': 0.5172057, 'raw_content': None}], 'response_time': 1.33}
# {'query': 'Jason Kapono total rebounds 2008-2009 season', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.landofbasketball.com/nba_players_game_logs/2009/jason_kapono.htm', 'title': 'Jason Kapono 2008-09 Basic Game Log - NBA Players Stats', 'content': 'Game by game statistics of Jason Kapono in the 2009 NBA Season and Playoffs. His Basic numbers including points, rebounds, assists, steals and blocks.', 'score': 0.74961954, 'raw_content': None}], 'response_time': 1.47}
# ---------- TextMessage (PlanningAgent) ----------
# 2. WebSearchAgent: Extract the total rebounds for Jason Kapono in the 2007-2008 and 2008-2009 seasons from the search results.
#
# After gathering the rebound data, the next step will be to calculate the percentage change in his rebounds between these two seasons.
# ---------- TextMessage (UserProxyAgent) ----------
# No questions , TERMINATE
# TaskResult(messages=[TextMessage(id='18674134-3b0a-4537-8424-2bc236c9ae74', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 8, 14, 11, 54, 779627, tzinfo=datetime.timezone.utc), content='Who was the Miami Heat player with the highest point in the 2006-2007 season, and what was the percentage change in his total rebounds between the 2007-2008 and 2008-2009 seasons?', type='TextMessage'), TextMessage(id='e0a0b05f-f4f4-4a20-b9cb-fcc095af420d', source='PlanningAgent', models_usage=RequestUsage(prompt_tokens=161, completion_tokens=130), metadata={}, created_at=datetime.datetime(2025, 8, 8, 14, 12, 3, 667043, tzinfo=datetime.timezone.utc), content="To answer these questions, we need to gather some specific historical data related to the Miami Heat player's performance stats for the specified seasons. Here's how we will break down the tasks:\n\n1. WebSearchAgent: Identify the Miami Heat player with the highest points in the 2006-2007 season.\n2. WebSearchAgent: Find the total rebounds for the identified player in the 2007-2008 and 2008-2009 seasons.\n3. DataAnalystAgent: Calculate the percentage change in the player's total rebounds between the 2007-2008 and 2008-2009 seasons.\n\nLet's proceed with these tasks.", type='TextMessage'), UserInputRequestedEvent(id='59fb0f28-7133-4a87-96dd-615f993db1c2', source='UserProxyAgent', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 8, 14, 12, 3, 671050, tzinfo=datetime.timezone.utc), request_id='05f9b5ec-7c2e-44f7-926d-39d796e16351', content='', type='UserInputRequestedEvent'), TextMessage(id='23d1c25f-b70d-4680-9e57-a61da8651ab6', source='UserProxyAgent', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 8, 14, 12, 13, 802248, tzinfo=datetime.timezone.utc), content='APPROVE', type='TextMessage'), ToolCallRequestEvent(id='c0d6eac1-580b-405c-84a3-7dffcfc414d8', source='WebSearchAgent', models_usage=RequestUsage(prompt_tokens=306, completion_tokens=27), metadata={}, created_at=datetime.datetime(2025, 8, 8, 14, 12, 16, 597307, tzinfo=datetime.timezone.utc), content=[FunctionCall(id='call_3KfGOqZqAaxDhVx3aiRAuo5f', arguments='{"query":"Miami Heat player with highest points in 2006-2007 season"}', name='search_web')], type='ToolCallRequestEvent'), ToolCallExecutionEvent(id='5f56de83-a0a5-4fa5-8701-14319bf6eded', source='WebSearchAgent', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 8, 14, 12, 19, 753376, tzinfo=datetime.timezone.utc), content=[FunctionExecutionResult(content="{'query': 'Miami Heat player with highest points in 2006-2007 season', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.landofbasketball.com/stats_by_team/2006_2007_heat_rs.htm', 'title': '2006-07 Miami Heat Player Stats - Regular Season', 'content': '**Season:** Stats / Season Series Stats / Playoff Series # 2006-07 Miami Heat Player Stats - Regular Season ## Stats per game recorded by the 2006-2007 Heat players in the Regular Season, including games, points, rebounds, assists, steals, blocks and shooting details. ### 2006-07 Miami Heat - NBA Regular Season Stats | Jason Kapono | 67 | 26.4 | 10.9 | 0.4 | 2.3 | 2.7 | 1.2 | 0.6 | 0.0 | 1.0 | 2.0 | | Jason Williams | 61 | 30.6 | 10.9 | 0.3 | 2.0 | 2.3 | 5.3 | 1.0 | 0.0 | 1.6 | 1.1 | | Jason Kapono | 10.9 |  | 4.1 | 8.4 | .494 | 1.6 | 3.1 | .514 | 1.0 | 1.1 | .892 |', 'score': 0.9441409, 'raw_content': None}], 'response_time': 1.23}", name='search_web', call_id='call_3KfGOqZqAaxDhVx3aiRAuo5f', is_error=False)], type='ToolCallExecutionEvent'), ToolCallSummaryMessage(id='f797b735-2475-4f56-96b2-0fe6ffb9c102', source='WebSearchAgent', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 8, 14, 12, 19, 753376, tzinfo=datetime.timezone.utc), content="{'query': 'Miami Heat player with highest points in 2006-2007 season', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.landofbasketbal ...
